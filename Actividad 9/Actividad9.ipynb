# %% [markdown]
# # $\underline{\text{ACTIVIDAD 9}}$
#
# Gustavo Medina
# 19/03/2021

# %%
#Primero, declaramos las bibliotecas a utilizar

import numpy as np
import scipy.linalg as la
from numpy.linalg import matrix_power as mpow
import matplotlib.pyplot as plt
import pylab as pl
import pandas as pd

# %% [markdown]
# # $\underline{\text{Ejercicio 1:}}$

# %%
#Primero, calculamos los eigenvalues de la atriz:
c=np.array([[0,1],[-1,0]])

print('Nuestra matriz es ')
print(c) 
print()

eival_1, eivec_1=la.eig(c)

print('Los eigenvectores')
print(eivec_1)
print()

print('Los eigenvalores')
print(eival_1)
# Out:
# Nuestra matriz es
# [[ 0  1]
#  [-1  0]]
#
# Los eigenvectores
# [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]
#
# Los eigenvalores
# [0.+1.j 0.-1.j]

# %% [markdown]
# Siendo entonces que nuestra parte real a es 0 y la parte imaginaria b es igual a 1 $$ x(t)=[c_1(cos(bt)+isen(bt))v_1+c_2(cos(bt)-isen(bt))v_2]e^{at}$$
#
# El punto critico lo podemos ubicar como centro ya que a=0 y b siendo 1 es mayor que 0. La solucion $$x(t)=c_1(cos(t)+isen(t))v_1+c_2(cos(t)-isen(t))v_2$$

# %%
v1_1=eivec_1[:,0]
print(v1_1)
v2_1=eivec_1[:,1]
print(v2_1)
# Out:
# [0.70710678+0.j         0.        +0.70710678j]
# [0.70710678-0.j         0.        -0.70710678j]

# %%
t=np.linspace(-10,15,200)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 
for c1 in [0,1,2,3,4]:

  for s in [-1,1]:
    x=s*c1*np.sin(t)-s*c1*np.cos(t)
    y=s*c1*np.sin(t)+s*c1*np.cos(t)
    plt.plot(x,y)



plt.grid();
plt.ylim(-20, 50)
plt.xlim(-10,10)
plt.legend(loc='best');
plt.xlabel('x(t)');
plt.ylabel('y(t)');
plt.title('Soluciones x(t), y(t)');
plt.show();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # $\underline{\text{Ejercicio 2:}}$

# %%
B=np.array([[1,0],[0,1]])
eival2, eivec2=la.eig(B)

print('Nuestra matriz es ')
print(B) 
print()

print('Los eigenvectores')
print(eivec2)
print()

print('Los eigenvalores')
print(eival2)
# Out:
# Nuestra matriz es
# [[1 0]
#  [0 1]]
#
# Los eigenvectores
# [[1. 0.]
#  [0. 1.]]
#
# Los eigenvalores
# [1.+0.j 1.+0.j]

# %%
TraceB=np.trace(B)
print('La traza es')
print(TraceB)
print()
DetB=la.det(B)
print('El determinante es')
print(DetB)
print()
print('Delta es =')
print((TraceB)**2-4*(DetB))
print()
# Out:
# La traza es
# 2
#
# El determinante es
# 1.0
#
# Delta es =
# 0.0

# %%
t=np.linspace(0,5,200)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 
for c1 in [1,2,3,4]:
  for c2 in [1,2,3,4]:
    x=c1*np.exp(t)
    y=c2*np.exp(t)
    plt.plot(t,x,'r-');
    plt.plot(t,y,'b-', alpha=0.5);
plt.grid();
plt.ylim(0, 50)
plt.xlim(-10,10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
t=np.linspace(0,5,200)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 
for c1 in [1,2,3,4]:
  for c2 in [1,2,3,4]:
    x=c1*np.exp(t)
    y=c2*np.exp(t)
    label='c1=',c1,'c2=',c2
    plt.plot(x,y,label=label);
    
    
    
plt.plot(np.exp(t),np.exp(t),'crimson',ls='--');
plt.grid();
plt.ylim(0, 50)
plt.xlim(-10,10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %% [markdown]
# # $\underline{\text{Ejercicio 3}}$
#
#
# $$ \frac{d^2x}{dt^2}+w^2_0x=0, w_0>0 $$
#
# Lo podemos escribir como $$ \frac{dx}{dt}=w\\ \frac{d^2x}{dt^2}=-w_0^2x\\ \\ \frac{dx}{dt}=w \frac{dw}{dt}=-w_0^2x $$ De modo que $$ \frac{d\vec{x}}{dt}=\begin{bmatrix} 0 &amp; 1\\ -w_0^2 &amp; 0 \end{bmatrix} \begin{bmatrix} x\\ w \end{bmatrix} $$ Asumimos que $w_0$ es el valor inicial de la primera derivada y como nos dicen este es mayor a cero.\ $\lambda$ sera entonces $(-\lambda)(-\lambda)-(-w_0^2)(1)=\lambda^2+w_0^2=0$
#
# despejando lambda
#
# $\lambda=\sqrt{-w_o^2}$ De modo que $\lambda$ sera imaginario y tendra la forma $$X_1=[B_1cos\beta t-B_2sen\beta t]e^{\alpha t}\\ X_2=[B_2cos\beta t+B_1sen\beta t]e^{\alpha t}$$ donde B_1= parte real de los componentes de un eigenvector columna y B_2 es la parte imaginaria fuente:zill 9nva edicion pag.322 $$X=[C_1(B_1 cos \beta t-B_2 sen \beta t)+C_2(B_2cos\beta t+B_1sen\beta t)]e^{\alpha t}$$

# %%
t=np.linspace(0,5,500)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 

for b in [1,2,3,4,5,6]:
  for c1 in [1,2,3]:
    for c2 in[3,4,5,6]:
      x=[]
      y=[]
      for i in t:
        A3=np.array([[0,1],[-1*b^2,0]])
        eigval_3, eigvec_3 = la.eig(A3)
        B11= (eigvec_3[:,0].real).reshape(2,1)
        B21=(eigvec_3[:,1].real).reshape(2,1)
        B12=(eigvec_3[:,0].imag).reshape(2,1)
        B22=(eigvec_3[:,1].imag).reshape(2,1)
        a=eigval_3.real
        beta1=abs(eigval_3[0].imag)
        X=(c1*(B11*np.cos(abs(eigval_3[0].imag)*i)-B12*np.sin(abs(eigval_3[0].imag)*i))+c2*(B21*np.cos(abs(eigval_3[1].imag)*i)+B22*np.sin(abs(eigval_3[1].imag)*i)))*np.exp(a*i)
        x.extend(X[0])
        y.extend(X[1])
      plt.plot(x,y)
plt.grid();

plt.legend(loc='best');
plt.xlabel('x');
plt.ylabel('y');
plt.title('y vs x');
plt.show();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # $\underline{\text{Ejercicio 4}}$
#
# $$ \frac{dx}{dt}=-2x\ \ (1)\\ \frac{dy}{dt}= 2z \ \ (2)\\ \frac{dz}{dt}= -2y \ \ (3) $$
#
# En este caso siendo $\vec{x}=(x,y,z)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x \\ y \\ z \end{bmatrix} =\begin{bmatrix} -2 &amp; 0 &amp; 0 \\ 0 &amp; 0 &amp; 2 \\ 0 &amp; -2 &amp; 0\\ \end{bmatrix} \begin{bmatrix} x \\ y \\ z \end{bmatrix} $$
#
# Punto critico es (0,0,0)
#
# Declararemos la matrix para ver como son los puntos de equilibrio

# %%
D=np.array([[-2,0,0],[0,0,2],[0,-2,0]])
print('Mi matriz es')
print(D)
print()
TraceD=np.trace(D)
print('La traza es')
print(TraceD)
print()
DetD=la.det(D)
print('El determinante es')
print(DetD)
print()
print('Delta es =')
print((TraceD)**2-4*(DetD))
print()
eival4, eivec4=la.eig(D)
print('Los eigenvalores son')
print(eival4)
print()
print('Los eigenvectores son')
print(eivec4)
# Out:
# Mi matriz es
# [[-2  0  0]
#  [ 0  0  2]
#  [ 0 -2  0]]
#
# La traza es
# -2
#
# El determinante es
# -8.0
#
# Delta es =
# 36.0
#
# Los eigenvalores son
# [ 0.+2.j  0.-2.j -2.+0.j]
#
# Los eigenvectores son
# [[ 0.        +0.j          0.        -0.j          1.        +0.j        ]
#  [-0.70710678+0.j         -0.70710678-0.j          0.        +0.j        ]
#  [ 0.        -0.70710678j  0.        +0.70710678j  0.        +0.j        ]]

# %%
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,50,300)
# defining all 3 axes
for c1 in [1,4]:
  for c2 in [1,4]:
    for c3 in [1,3]:

      z = c1*np.sin(2*t)-c2*np.cos(2*t)
      x = c3*np.exp(-2*t)
      y =c2*np.sin(2*t)+c1*np.cos(2*t)
      ax.plot3D(x, y, z)
# plotting
#ax.plot3D(x, y, z, 'green')
ax.set_title('Solucion en espacio fase')
plt.show()

# %%
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,50,300)
# defining all 3 axes
for c1 in [1,2,3,4]:
  for c2 in [1,2,3,4]:
    for c3 in [1,2,3,4]:

      z = c1*np.sin(2*t)-c2*np.cos(2*t)
      x = c3*np.exp(-2*t)
      y =c2*np.sin(2*t)+c1*np.cos(2*t)
      
      
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('Solcuion en espacio fase')
plt.show()

# %% [markdown]
# # $\underline{\text{Ejercicio 5:}}$
#
# $$ \frac{dx}{dt}=-x+z\ \ (1)\\ \frac{dy}{dt}= 3y \ \ (2)\\ \frac{dz}{dt}= -x-z \ \ (3) $$
#
# En este caso siendo $\vec{x}=(x,y,z)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x \\ y \\ z \end{bmatrix} =A \begin{bmatrix} x \\ y \\ z \end{bmatrix} =\begin{bmatrix} -1 &amp; 0 &amp; 1 \\ 0 &amp; 3 &amp; 0 \\ -1 &amp; 0 &amp; -1\\ \end{bmatrix} \begin{bmatrix} x \\ y \\ z \end{bmatrix} $$

# %%
A5=np.array([[-1,0,1],[0,3,0],[-1,0,-1]])
print('La matriz en cuestion A es ')
print(A5)
print()

eival5, eivec5=la.eig(A5)
print('Los eigenvalores son')
print(eival5)
print()
print('Los eigenvectores son')
print(eivec5)
# Out:
# La matriz en cuestion A es
# [[-1  0  1]
#  [ 0  3  0]
#  [-1  0 -1]]
#
# Los eigenvalores son
# [-1.+1.j -1.-1.j  3.+0.j]
#
# Los eigenvectores son
# [[0.70710678+0.j         0.70710678-0.j         0.        +0.j        ]
#  [0.        +0.j         0.        -0.j         1.        +0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j 0.        +0.j        ]]

# %%
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,50,300)
# defining all 3 axes
for c1 in [1,4]:
  for c2 in [1,4]:
    for c3 in [1,3]:

      x= (c1*np.sin(t)-c2*np.cos(t))*np.exp(-t)
      y = (c1*np.cos(t)+c2*np.sin(t))*np.exp(-t)
      z =c3*np.exp(3*t)
      ax.plot3D(x, y, z)
# plotting
#ax.plot3D(x, y, z, 'green')
ax.set_title('Solucion en espacio fase')
plt.xlim(-5,5)
plt.ylim(-5,5)

plt.show()

# %% [markdown]
# # $\underline{\text{Ejercicio 6:}}$
#
# $$ \frac{dx}{dt}=-x\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ (1)\\ \frac{dy}{dt}= x+2y \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ (2)\\ x(0)=0, \ \ \ \ y(0)=3\ \ \ (3) $$
#
# En este caso siendo $\vec{x}=(x,y)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x \\ y \end{bmatrix} =A \begin{bmatrix} x \\ y \end{bmatrix} =\begin{bmatrix} -1 &amp; 0 \\ 1 &amp; 2 \\ \end{bmatrix} \begin{bmatrix} x \\ y \\ \end{bmatrix} $$

# %%
A6=np.array([[-1,0],[1,2]])

print('La matriz en cuestion A es ')
print(A6)
print()

eival6, eivec6=la.eig(A6)
print('Los eigenvalores son')
print(eival6)
print()
print('Los vectores correspondientes son')
print(eivec6)
# Out:
# La matriz en cuestion A es
# [[-1  0]
#  [ 1  2]]
#
# Los eigenvalores son
# [ 2.+0.j -1.+0.j]
#
# Los vectores correspondientes son
# [[ 0.          0.9486833 ]
#  [ 1.         -0.31622777]]

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt

def dX_dt(X, t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ -1*X[0] ,
                  X[0]+2*X[1]])
    
# Los puntos críticos del sistema
X_f0 = np.array([     0. ,  0.])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
# En los puntos críticos se anulan las derivadas. 
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
lambda1 = eival6[0]
lambda2 = eival6[1]
print('Eigenvalores')
print('lambda1= ', lambda1)
print('lambda2= ', lambda2)
print(' ')
print('Eigenvectores')
v1 = eivec6[:,0]
v2 = eivec6[:,1]
print('v1=',v1)
print('v2=',v2)
# Out:
# Eigenvalores
# lambda1=  (2+0j)
# lambda2=  (-1+0j)
#
# Eigenvectores
# v1= [0. 1.]
# v2= [ 0.9486833  -0.31622777]

# %%
t = np.linspace(1, 5,  500)              # Rango de tiempo de integración
X0 = np.array([0, 3])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x,y=X.T
plt.plot(x, y, 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(-1, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# # $\underline{\text{Ejercicio 7:}}$
#
# $$ \frac{dx}{dt}=2x +y \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ (1)\\ \frac{dy}{dt}= x+ y \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ (2)\\ x(1)=1, \ \ \ \ y(1)=1\ \ \ (3) $$
#
# En este caso siendo $\vec{x}=(x,y)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x \\ y \end{bmatrix} =A \begin{bmatrix} x \\ y \end{bmatrix} =\begin{bmatrix} 2 &amp; 1 \\ 1 &amp; 1 \\ \end{bmatrix} \begin{bmatrix} x \\ y \\ \end{bmatrix} $$

# %%
A7=np.array([[2,1],[1,1]])

print('La matriz en cuestion A es ')
print(A7)
print()

eival7, eivec7=la.eig(A7)
print('Los eigenvalores son')
print(eival7)
print()
print('Los vectores correspondientes son')
print(eivec7)
# Out:
# La matriz en cuestion A es
# [[2 1]
#  [1 1]]
#
# Los eigenvalores son
# [2.61803399+0.j 0.38196601+0.j]
#
# Los vectores correspondientes son
# [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]

# %%
TraceA=np.trace(A7)
print('La traza es')
print(TraceA)
print()
DetA=la.det(A7)
print('El determinante es')
print(DetA)
print()
print('Delta es =')
print((TraceA)**2-4*(DetA))
print()
# Out:
# La traza es
# 3
#
# El determinante es
# 1.0
#
# Delta es =
# 5.0

# %%
def dX_dt(X, t=1):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ 2*X[0] + X[1] ,
                  X[0]+X[1]])
    
X_f0=np.array([0.0,  0.0  ])
#Puntos criticos 
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# True

# %%
t = np.linspace(1, 5,  500)              # Rango de tiempo de integración
X0 = np.array([1, 1])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x,y=X.T
plt.plot(x, y, 'orange')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# # $\underline{\text{Ejercicio 8:}}$

# %%
A8=np.array([[0,3],[1,-2]])

print('La matriz en cuestion A es ')
print(A8)
print()

eival8, eivec8=la.eig(A8)
print('Los eigenvalores son')
print(eival8)
print()
print('Los vectores correspondientes son')
print(eivec8)
# Out:
# La matriz en cuestion A es
# [[ 0  3]
#  [ 1 -2]]
#
# Los eigenvalores son
# [ 1.+0.j -3.+0.j]
#
# Los vectores correspondientes son
# [[ 0.9486833  -0.70710678]
#  [ 0.31622777  0.70710678]]

# %%
TraceA=np.trace(A8)
print('La traza es')
print(TraceA)
print()
DetA=la.det(A8)
print('El determinante es')
print(DetA)
print()
print('Delta es =')
print((TraceA)**2-4*(DetA))
print()
# Out:
# La traza es
# -2
#
# El determinante es
# -3.0
#
# Delta es =
# 16.0

# %%
def dX_dt(X,t=0):
  return np.array([0*X[0]+3*X[1] , X[0]-2*X[1]])

X_f0=np.array([0.0   , 0.0   ])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
t = np.linspace(1, 5,  500)              # Rango de tiempo de integración
X0 = np.array([0, 3])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x, y = X.T
plt.plot(x, y, 'brown')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# # $\underline{\text{Ejercicio 9:}}$

# %%
A9=np.array([[2,0,0],[0,-1,0],[0,2,-3]])
print('La matriz A en cuestion es ')
print(A9)
print('')
eival9, eivec9=linalg.eig(A9)
lambda1_9=eival9[0]
lambda2_9=eival9[1]
lambda3_9=eival9[2]
print('Los eigenvalores son ')
print('lambda1= ',lambda1_9)
print('')

print('lambda2= ',lambda2_9)
print('')

print('lambda3= ',lambda3_9)
print('')
v1=eivec9[:,0]
v2=eivec9[:,1]
v3=eivec9[:,2]
print('Los eigenvectores son ')
print('v1=',v1)
print('')
print('v2=',v2)
print('')
print('v3=',v3)
# Out:
# La matriz A en cuestion es
# [[ 2  0  0]
#  [ 0 -1  0]
#  [ 0  2 -3]]
#
# Los eigenvalores son
# lambda1=  (2+0j)
#
# lambda2=  (-3+0j)
#
# lambda3=  (-1+0j)
#
# Los eigenvectores son
# v1= [1. 0. 0.]
#
# v2= [0. 0. 1.]
#
# v3= [0.         0.70710678 0.70710678]

# %%
#Ya tenemos A9
def dX_dt(X,t=0):
  return np.array([2*X[0],
                   -1*X[1],
                   2*X[1]-3*X[2]])
X_f0=np.array([0.0  ,  0.0 ,   0.0 ])
#Puntos criticos del sistema

print('Puntos criticos del sistema son ')
print(X_f0)
print()

#En los puntos criticos se anulan las derivadas
all(dX_dt(X_f0)==np.zeros(3))

#Ya tenemos los eigenvalores y vectores

t=np.linspace(0,15,700)
fig = plt.figure()
ax = plt.axes(projection ='3d')


for b in [1,2,3,4,5]:
  X0=np.array([0,-1*b,b])
  X, infodict = integrate.odeint(dX_dt,X0,t,full_output=True)
  infodict['message']
  x ,y ,z = X.T
  ax.plot3D(x, y, z,)
  #legend='Para b igual a ',b
  #plt.legend(legend)


label='Familias de soluciónes en el espacio fase (x(t),y(t),z(t))'
ax.set_title(label)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel('x');
plt.ylabel('y');
plt.show()
# Out:
# Puntos criticos del sistema son
# [0. 0. 0.]

# %% [markdown]
# # $\underline{\text{Ejercicio 10:}}$
#
#
#
# Se tiene el siguiente sistema de resortes acoplados con dos masas
#
# El sistema esta sujeto del primer resorte de la izquierda. Cuando el sistema se deja en reposo, las longitudes de los resortes son $L_1$ y $L_2$.
#
# Las ecuaciones de movimiento estan dadas por las siguientes ecuaciones diferenciales acopladas:
#
# Ecuaciones.png
#
# Encuentre las soluciones como funciones de $t$ y grafíquelas, así como las trayectorias en el espacio fase.
#
# Suponga que $L_1=L_2=1$ y que las masas son iguales $m_1=m_2=1$.
#
# Tenemos dos ecuaciones de segundo grado que podemos escribir como dos ecuaciones de primer grado.
#
# $x_1=x_1$ , $x_2=x_2$ , $x_3=\frac{dx_1}{dt}$ , $x_4=\frac{dx_2}{dt}$
#
# Entonces puedo escribir dos ecuaciones de la primera ecuacion
# $$\frac{dx_1}{dt}=x_3\\ \frac{dx_3}{dt}=\frac{k_2(x_2-x_1-L_2)-k_1(x_1-L_1)-b_1x_3}{m_1}\\ \frac{dx_2}{dt}=x_4\\ \frac{dx_4}{dt}=\frac{-k_2(x_2-x_1-L_2)-b_2x_4}{m_2}$$
# $$\frac{dx_1}{dt}=x_3\\ \frac{dx_3}{dt}=\frac{k_2}{m_1}x_2-\frac{k_2}{m_1}x_1-\frac{k_2}{m_1}L_2-\frac{k_1}{m_1}x_1+\frac{k_1}{m_1}L_1-\frac{b_1}{m_1}x_3\\ \frac{dx_2}{dt}=x_4\\ \frac{dx_4}{dt}=\frac{-k_2}{m_2}x_2+\frac{k_2}{m_2}x_1+\frac{k_2}{m_2}L_2-\frac{b_2}{m_2}x_4$$
#
# Terminos similares y las constantes al final de rojo
# $$\frac{dx_1}{dt}=x_3\\ \frac{dx_3}{dt}=-\frac{k_2+k_1}{m_1}x_1-\frac{b_1}{m_1}x_3 + \frac{k_2}{m_1}x_2 -\frac{k_2}{m_1}L_2+\frac{k_1}{m_1}L_1\\ \frac{dx_2}{dt}=x_4\\ \frac{dx_4}{dt}=\frac{-k_2}{m_2}x_2+\frac{k_2}{m_2}x_1+\frac{k_2}{m_2}L_2-\frac{b_2}{m_2}x_4$$
#
# \
# $$\begin{bmatrix} \frac{dx_1}{dt} &amp; 0 &amp; x_3 &amp; 0 &amp; 0 \\ \frac{dx_3}{dt} &amp; -\frac{k_2+k_1}{m_1}x_1 &amp; -\frac{b_1}{m_1}x_3 &amp; \frac{k_2}{m_1}x_2 &amp; 0 \\ \frac{dx_2}{dt} &amp; 0 &amp; 0 &amp; 0 &amp; x_4\\ \frac{dx_4}{dt} &amp; \frac{k_2}{m_2}x_1 &amp; 0 &amp; \frac{-k_2}{m_2}x_2 &amp; -\frac{b_2}{m_2}x_4 \end{bmatrix}$$
#
# +$$\begin{bmatrix} 0\\ -\frac{k_2}{m_1}L_2+\frac{k_1}{m_1}L_1\\ 0\\ \frac{k_2}{m_2}L_2\\ \end{bmatrix}$$
#
# En este caso siendo $\vec{x}=(x_1,x_3,x_2,x_4)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} =A \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix}+C =\begin{bmatrix} 0 &amp; 1 &amp; 0 &amp; 0 \\ -\frac{k_2+k_1}{m_1} &amp; -\frac{b_1}{m_1} &amp; \frac{k_2}{m_1} &amp; 0 \\ 0 &amp; 0 &amp; 0 &amp; 1 \\ \frac{k_2}{m_2} &amp; 0 &amp; \frac{-k_2}{m_2} &amp; -\frac{b_2}{m_2}\\ \end{bmatrix} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} +\begin{bmatrix} 0\\ -\frac{k_2}{m_1}L_2+\frac{k_1}{m_1}L_1\\ 0\\ \frac{k_2}{m_2}L_2\\ \end{bmatrix} $$
#
# 10.1) Encuentre los eigenvalores del sistema y diga como son las soluciones.
#
# buscamos los eigenvalores del sistema homogeneo De modo que nos queda $$\begin{bmatrix} 0-\lambda &amp; 1 &amp; 0 &amp; 0 \\ -\frac{k_2+k_1}{m_1} &amp; -\frac{b_1}{m_1}-\lambda &amp; \frac{k_2}{m_1} &amp; 0 \\ 0 &amp; 0 &amp; 0-\lambda &amp; 1 \\ \frac{k_2}{m_2} &amp; 0 &amp; \frac{-k_2}{m_2} &amp; -\frac{b_2}{m_2}-\lambda\\ \end{bmatrix}$$
#
# por cofactores por el reglon 3 $$ Det(A)=0\begin{bmatrix}1&amp;0&amp;0\\-\frac{b_1}{m_1}-\lambda&amp;\frac{k_2}{m_1}&amp;0\\ 0 &amp; -\frac{k_2}{m_2} &amp; -\frac{b_2}{m_2}-\lambda \end{bmatrix}+0\begin{bmatrix}0-\lambda&amp;0&amp;0\\-\frac{k_2+k_1}{m_1}&amp;\frac{k_2}{m_1}&amp; 0\\ \frac{k_2}{m_2}&amp;-\frac{k_2}{m_1} &amp; -\frac{b_2}{m_2}-\lambda \end{bmatrix}+(0-\lambda)\begin{bmatrix}0-\lambda&amp;1&amp;0\\ -\frac{k_2+k_1}{m_1}&amp;-\frac{b_1}{m_1}-\lambda&amp;0 \\ \frac{k_2}{m_2}&amp;0&amp;-\frac{b_2}{m_2}-\lambda \end{bmatrix}+1\begin{bmatrix}0-\lambda &amp; 1 &amp;0\\ -\frac{k_2+k_1}{m_1} &amp; -\frac{b_1}{m_1}-\lambda &amp; \frac{k_2}{m_1} \\ \frac{k_2}{m_2} &amp; 0 &amp; -\frac{k_2}{m_2}\end{bmatrix} $$
#
# Como vemos dos son cero y depende de $-\lambda$ y 1 por el coeficiente de las matrices siendo entonces
#
# $$(-\lambda)(
#
# Determinante de la matriz
#
# $\frac{k_2\left(k_2-\lambda\left(-b_1-\lambda m_1\right)\right)+ \lambda \left(\lambda \left(-b_2-\lambda m_2\right)\left(-b_1-\lambda m_1\right)-\left(k_2+k_1\right)\left(-b_2-\lambda m_2 \right)\right)}{m_1 m_2}$
#
# Si $$k_1=j\\ k_2=k\\ \lambda=p\\ b_1=c\\ b_2=b\\ m_1=n\\ m_2=m\\ $$
#
# $\frac{k\left(j-l\left(-c-ln\right)\right)+l\left(l\left(-b-lm\right)\left(-c-ln\right)-\left(k+j\right)\left(-b-lm\right)\right)}{nm}=0$
# $$ kj-kl(-c-ln)+l^2(-b-lm)(-c-ln)-l(k+j)(-b-lm)]$$$$kj+klc+kl^2n+l^2(bc+bln+lmc+l^2mn)-l(-kb-klm-bj-jlm)]$$$$kj+klc+kl^2n+l^2(bc+bln+lmc+l^2mn)+l(kb+klm+bj+jlm)$$$$kj+klc+kl^2n+bcl^2+bl^3n+l^3mc+l^4mn+lkb+kl^2m+bjl+jl^2m$$
#
# uniendo terminos similares
# $$l^4mn+bl^3n+l^3mc+kl^2n+bcl^2+kl^2m+jl^2m+klc+lkb+bjl+kj=0$$
# In [28]:
#
#
# Recordando del enunciado que $L_1=L_2=1$ y $m_1=m_2=1$
# $$\lambda^4m_2m_1+b_2\lambda^3m_1+\lambda^3m_2b_1+k_2\lambda^2m_1+b_2b_1\lambda^2+k_2\lambda^2m_2+k_1\lambda^2m_2+k_2\lambda b_1+\lambda k_2 b_2+b_2k_1\lambda+k_2k_1=0$$
#
# \
#
# \
# $$\lambda^4+b_2\lambda^3+\lambda^3b_1+k_2\lambda^2+b_2b_1\lambda^2+k_2\lambda^2+k_1\lambda^2+k_2\lambda b_1+\lambda k_2 b_2+b_2k_1\lambda+k_2k_1=0 $$
# $$\lambda^4+(b_2+b_1)\lambda^3+(k_2+b_1b_2+k_2+k_1)\lambda^2+(k_2b_1+k_2b_2+k_1b_2)\lambda+k_2k_1=0$$
#
# Siendo una ecuacion de cuarto grado y buscamos los valores de landa para los cuales se cumple la ecuacion, es decir las raices de la ecuacion.
#
# 10.2) Caso sin fricción. $b_1=b_2=0$, $k_1=6$, $k_2=4$, condiciones iniciales $(x_1(0), x_1^{'}(0), x_2(0), x_2^{'}(0))=(1,0,4,0)$
#
# En este caso siendo $\vec{x}=(x_1,x_3,x_2,x_4)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} =A \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix}+C =\begin{bmatrix} 0 &amp; 1 &amp; 0 &amp; 0 \\ -\frac{k_2+k_1}{m_1} &amp; -\frac{b_1}{m_1} &amp; \frac{k_2}{m_1} &amp; 0 \\ 0 &amp; 0 &amp; 0 &amp; 1 \\ \frac{k_2}{m_2} &amp; 0 &amp; \frac{-k_2}{m_2} &amp; -\frac{b_2}{m_2}\\ \end{bmatrix} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} +\begin{bmatrix} 0\\ -\frac{k_2}{m_1}L_2+\frac{k_1}{m_1}L_1\\ 0\\ \frac{k_2}{m_2}L_2\\ \end{bmatrix} $$
#
# $\vec{x}=(x_1,x_3,x_2,x_4)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} =A \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix}+C =\begin{bmatrix} 0 &amp; 1 &amp; 0 &amp; 0 \\ -(k_2+k_1) &amp; -b_1 &amp; k_2 &amp; 0 \\ 0 &amp; 0 &amp; 0 &amp; 1 \\ k_2 &amp; 0 &amp; -k_2 &amp; -b_2\\ \end{bmatrix} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} +\begin{bmatrix} 0\\ -k_2+k_1\\ 0\\ k_2\\ \end{bmatrix} $$
#
# $\vec{x}=(x_1,x_3,x_2,x_4)$ $$ \frac{d \vec{x} }{dt}=\frac{d}{dt} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} =A \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix}+C =\begin{bmatrix} 0 &amp; 1 &amp; 0 &amp; 0 \\ -(4+6) &amp; 0 &amp; 4 &amp; 0 \\ 0 &amp; 0 &amp; 0 &amp; 1 \\ 4 &amp; 0 &amp; -4 &amp; 0\\ \end{bmatrix} \begin{bmatrix} x_1 \\ x_3 \\ x_2 \\ x_4 \\ \end{bmatrix} +\begin{bmatrix} 0\\ -4+6\\ 0\\ 4\\ \end{bmatrix} $$
# $$\frac{dx_1}{dt}=x_3\\ \frac{dx_3}{dt}=-\frac{k_2+k_1}{m_1}x_1-\frac{b_1}{m_1}x_3 + \frac{k_2}{m_1}x_2 -\frac{k_2}{m_1}L_2+\frac{k_1}{m_1}L_1\\ \frac{dx_2}{dt}=x_4\\ \frac{dx_4}{dt}=\frac{-k_2}{m_2}x_2+\frac{k_2}{m_2}x_1+\frac{k_2}{m_2}L_2-\frac{b_2}{m_2}x_4$$

# %%
#La parte homogenea
#Condiciones iniciales
k2=4
k1=6
b1=0
b2=0
A10=np.array([[0,1,0,0],[-1*(k2+k1),-1*b1,k2,0],[0,0,0,1],[k2,0,-1*k2,-1*b2]])
print('La matriz en cuestion es ')
print(A10)
print()
C=np.array([[0],[2],[0],[4]])
def dX_dt(X,t=0):
  return np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
# Out:
# La matriz en cuestion es
# [[  0   1   0   0]
#  [-10   0   4   0]
#  [  0   0   0   1]
#  [  4   0  -4   0]]

# %%
C_sol=la.solve(A10,-1*C)
print(C_sol)
# Out:
# [[1.]
#  [0.]
#  [2.]
#  [0.]]

# %%
#Puntos criticos del sistema
X_f0=np.array([0.0  , 0.0  , 0.0  , 0.0  ])
#Usando matriz aumentada de gauss
#Condiciones iniciales
#X0=1.0  , 0.0  ,4.0  , 0.0  
#pero X(0)=X_g(0)+X_p(0)
# y X_p es la solucion del sistema con costantes
# es decir C_sol despejamos X_g(0) para utilizarla al resolver la parte homogenea
#[1.0  , 0.0  ,4.0  , 0.0  ]-[1,0,2,0]=[0,0,2,0]
X0=np.array([0.0  , 0.0  ,2.0  , 0.0  ])

print('Puntos criticos del sistema para los valores dados')
print('X_f0=   ',X_f0)

#checamos que la derivada si sea 0 en los puntos criticos
#all(dX_dt(X_f0)== np.zeros(4) ) and all(dX_dt(X_f1)==np.zeros(4))
all(dX_dt(X_f0) == np.zeros(4) ) #and all(dX_dt(X_f1) == np.zeros(4))
# Out:
# Puntos criticos del sistema para los valores dados
# X_f0=    [0. 0. 0. 0.]
# True

# %%
##Definimos el jacobiano evaluado en X
#np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
#                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
def d2X_dt2(X,t=0):
  return np.array([ [0  ,         1 ,    0 , 0], 
                   [-1*(k2+k1), -1*b1,   k2,  0 ], 
                   [0,               0,    0,   1],
                  [k2 ,  0  ,  -1*k2,  0   ]])
#Jacobiano evaluado en el punto critico
A_f1=d2X_dt2(X_f0)
print('Jacobiano evaluado en punto critico')
print(A_f1)
lambda1,lambda2,lambda3,lambda4=linalg.eigvals(A_f1)
print('eigenvalores del jacobiano en X')
print(lambda1)
print(lambda2)
print(lambda3)
print(lambda4)
#Todos tienen parte real e imaginaria
# Out:
# Jacobiano evaluado en punto critico
# [[  0   1   0   0]
#  [-10   0   4   0]
#  [  0   0   0   1]
#  [  4   0  -4   0]]
# eigenvalores del jacobiano en X
# (2.220446049250313e-16+3.464101615137756j)
# (2.220446049250313e-16-3.464101615137756j)
# (-1.3877787807814457e-16+1.414213562373095j)
# (-1.3877787807814457e-16-1.414213562373095j)

# %%
T_f1 = 2*np.pi/abs(lambda1) 
print('Periodo:', T_f1)
#T_f2 = 2*np.pi/abs(lambda3) 
#print('Periodo 2:', T_f1)
# Out:
# Periodo: 1.813799364234217

# %%
#Ahora si busquemos la solucion
t=np.linspace(0,30,1000)

X,infodict=integrate.odeint(dX_dt,X0,t,full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x1, 'r-', label='masa 1');
plt.plot(t, x2, 'b-', label='masa 2');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('ubicacion');
plt.title('Evolucion de un sistema compuesto');
plt.show();

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt
from matplotlib import cm


# Graficamos la familia de soluciones en el espacio fase para distintas condiciones iniciales

values  = np.linspace(1, 10, 1) 
# posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values))) 
 # colores para cada trayectoria
plt.figure(figsize=(12, 8)); 

#-------------------------------------------------------
# grafica las trayectorias
for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,2], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[0], X0[2]) )
ymax = plt.ylim(ymin=0)[1]                        # get axis limits
xmax = plt.xlim(xmin=0)[1]

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,1], X[:,3], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[1], X0[3]) )
#-------------------------------------------------------
# define una malla y calcula la pendiente (dirección) en cada punto

y2max= plt.ylim(ymin=0)[1]   
x2max= plt.xlim(xmin=0)[1] 
nb_points   = 20

x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)
x2 = np.linspace(0, x2max, nb_points)
y2 = np.linspace(0, y2max, nb_points)

X1 , Y1 = np.meshgrid(x, y)     
X2 , Y2 = np.meshgrid(x2, y2)                    # crea la malla
DX1, DY1, DX2, DY2 = dX_dt([X1, Y1, X2  , Y2]) 
#dX_df es una funcion                     # calcula la tasa de crecimiento
#De 4 componentes necesito la de x1 y x2


M = (np.hypot(DX1, DY1))                           # distancia euclideana 
M[ M == 0] = 1.                                 # Evita divisiones entre 0 
DX1 /= M                                        # Normaliza el tamaño de cada flecha
DY1 /= M

#-------------------------------------------------------
# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento

plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.jet)
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()

# %%
#La parte homogenea
#Condiciones iniciales
k2=4
k1=6
b1=0.1
b2=0.2
A10=np.array([[0,1,0,0],[-1*(k2+k1),-1*b1,k2,0],[0,0,0,1],[k2,0,-1*k2,-1*b2]])
print('La matriz en cuestion es ')
print(A10)
print()
C=np.array([[0],[2],[0],[4]])
def dX_dt(X,t=0):
  return np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
# Out:
# La matriz en cuestion es
# [[  0.    1.    0.    0. ]
#  [-10.   -0.1   4.    0. ]
#  [  0.    0.    0.    1. ]
#  [  4.    0.   -4.   -0.2]]

# %%
C_sol=la.solve(A10,-1*C)
print(C_sol)
# Out:
# [[1.]
#  [0.]
#  [2.]
#  [0.]]

# %%
#Puntos criticos del sistema
X_f0=np.array([0.0  , 0.0  , 0.0  , 0.0  ])
#Usando matriz aumentada de gauss
#Condiciones iniciales
X0=np.array([0.0  , 0.0  ,2.0  , 0.0  ])

print('Puntos criticos del sistema para los valores dados')
print('X_f0=   ',X_f0)

#checamos que la derivada si sea 0 en los puntos criticos
#all(dX_dt(X_f0)== np.zeros(4) ) and all(dX_dt(X_f1)==np.zeros(4))
all(dX_dt(X_f0) == np.zeros(4) ) #and all(dX_dt(X_f1) == np.zeros(4))
# Out:
# Puntos criticos del sistema para los valores dados
# X_f0=    [0. 0. 0. 0.]
# True

# %%
##Definimos el jacobiano evaluado en X
#np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
#                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
def d2X_dt2(X,t=0):
  return np.array([ [0  ,         1 ,    0 , 0], 
                   [-1*(k2+k1), -1*b1,   k2,  0 ], 
                   [0,               0,    0,   1],
                  [k2 ,  0  ,  -1*k2,  0   ]])
#Jacobiano evaluado en el punto critico
A_f1=d2X_dt2(X_f0)
print('Jacobiano evaluado en punto critico')
print(A_f1)
lambda1,lambda2,lambda3,lambda4=linalg.eigvals(A_f1)
print('eigenvalores del jacobiano en X')
print(lambda1)
print(lambda2)
print(lambda3)
print(lambda4)
#Todos tienen parte real e imaginaria
# Out:
# Jacobiano evaluado en punto critico
# [[  0.    1.    0.    0. ]
#  [-10.   -0.1   4.    0. ]
#  [  0.    0.    0.    1. ]
#  [  4.    0.   -4.    0. ]]
# eigenvalores del jacobiano en X
# (-0.03999936001028768+3.463593494852212j)
# (-0.03999936001028768-3.463593494852212j)
# (-0.010000639989712207+1.414291364612996j)
# (-0.010000639989712207-1.414291364612996j)

# %%
T_f1 = 2*np.pi/abs(lambda1) 
print('Periodo:', T_f1)
#T_f2 = 2*np.pi/abs(lambda3) 
#print('Periodo 2:', T_f1)
# Out:
# Periodo: 1.8139444972104801

# %%
#Ahora si busquemos la solucion
t=np.linspace(0,30,1000)

X,infodict=integrate.odeint(dX_dt,X0,t,full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x1, 'r-', label='masa 1');
plt.plot(t, x2, 'b-', label='masa 2');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('ubicacion');
plt.title('Evolucion de un sistema compuesto');
plt.show();

# %%
tr=np.linspace(0,500,5000)

X,infodict=integrate.odeint(dX_dt,X0,tr,full_output=True)
infodict['message']
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(tr, x1, 'r-', label='masa 1');
plt.plot(tr, x2, 'b-', label='masa 2');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('ubicacion');
plt.title('Evolucion de un sistema compuesto');
plt.show();

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt
from matplotlib import cm


# Graficamos la familia de soluciones en el espacio fase para distintas condiciones iniciales

values  = np.linspace(1, 10, 1) 
# posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values))) 
 # colores para cada trayectoria
plt.figure(figsize=(12, 8)); 

#-------------------------------------------------------
# grafica las trayectorias
for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,2], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[0], X0[2]) )
ymax = plt.ylim(ymin=0)[1]                        # get axis limits
xmax = plt.xlim(xmin=0)[1]

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,1], X[:,3], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[1], X0[3]) )
#-------------------------------------------------------
# define una malla y calcula la pendiente (dirección) en cada punto

y2max= plt.ylim(ymin=0)[1]   
x2max= plt.xlim(xmin=0)[1] 
nb_points   = 20

x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)
x2 = np.linspace(0, x2max, nb_points)
y2 = np.linspace(0, y2max, nb_points)

X1 , Y1 = np.meshgrid(x, y)     
X2 , Y2 = np.meshgrid(x2, y2)                    # crea la malla
DX1, DY1, DX2, DY2 = dX_dt([X1, Y1, X2  , Y2]) 
#dX_df es una funcion                     # calcula la tasa de crecimiento
#De 4 componentes necesito la de x1 y x2


M = (np.hypot(DX1, DY1))                           # distancia euclideana 
M[ M == 0] = 1.                                 # Evita divisiones entre 0 
DX1 /= M                                        # Normaliza el tamaño de cada flecha
DY1 /= M

#-------------------------------------------------------
# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento

plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.jet)
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()
